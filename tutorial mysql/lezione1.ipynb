# %%
import mysql.connector

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="root"
)

print(f'connessione con successo {mydb}')
# Out:
# connessione con successo <mysql.connector.connection.MySQLConnection object at 0x0000023E341DBBD0>
