# %%
import mysql.connector

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="root",
  database="mydatabase"
)

mycursor = mydb.cursor()

# %%
mycursor.execute("CREATE TABLE Cliente (nome VARCHAR(255), cognome VARCHAR(255), indirizzo VARCHAR(255))")

# %%
mycursor.execute("SHOW TABLES")

for x in mycursor:
  print(x)
# Out:
# ('cliente',)

# %%
mycursor.execute("ALTER TABLE Cliente ADD COLUMN id INT AUTO_INCREMENT PRIMARY KEY ");
