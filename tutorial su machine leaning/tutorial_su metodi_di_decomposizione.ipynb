# %%
#NMF: Non-Negative Matrix Factorization
#Utilizzato per decomporre dati non negativi, come immagini o dati 
#testuali.
from sklearn.decomposition import NMF
import numpy as np

# Crea dati non negativi di esempio
data = np.array([[1, 2], [3, 4], [5, 6]])
#print(data)

# Applica NMF
nmf = NMF(n_components=2, random_state=42)
components = nmf.fit_transform(data)

print("Componenti NMF:", components)
# Out:
# Componenti NMF: [[1.19684855 0.        ]
#  [0.75282266 0.72121572]
#  [0.1905593  1.48561981]]
# C:\Users\Roman\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\decomposition\_nmf.py:1728: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(

# %%
#TruncatedSVD: Singular Value Decomposition Troncata
#Utilizzato per ridurre la dimensionalità di dati sparsi, 
#come quelli presenti in applicazioni di NLP.
