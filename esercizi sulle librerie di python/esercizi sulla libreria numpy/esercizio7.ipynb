# %% [markdown]
# ## Esercizio 7
# * Genera un array casuale di 100 numeri interi tra 1 e 100.
# * Filtra solo i numeri divisibili per 3 ma non per 5.
# * Conta quanti numeri soddisfano questa condizione.

# %%
import numpy as np

# %%
v1 = np.random.randint(1, 101, size=100)
v1
# Out:
# array([68, 81, 29, 17, 63, 68, 91,  1, 59, 36, 74, 13, 78, 92, 64,  7, 12,
#        29, 50, 67,  9, 15,  6, 78, 47, 16, 37, 28, 63,  3, 32, 69, 18, 95,
#        15, 15, 98, 34, 36, 63, 44, 23, 50, 67, 98, 34, 46, 13, 44, 68, 31,
#        26, 62, 33, 80,  7, 85, 67,  2, 49, 85, 86,  4, 86, 19, 83, 53, 68,
#        58, 42, 88, 97, 75, 85, 25, 76, 20, 44, 34, 37, 70, 42, 13, 16, 81,
#         8, 90, 34, 28, 29, 91, 85, 11,  2, 21, 38, 88, 75, 11, 62],
#       dtype=int32)

# %%
filtro = v1[(v1 % 3 == 0) & ~(v1 % 5 == 0)]
filtro
# Out:
# array([81, 63, 36, 78, 12,  9,  6, 78, 63,  3, 69, 18, 36, 63, 33, 42, 42,
#        81, 21], dtype=int32)

# %%
filtro.size
# Out:
# 19
