# %% [markdown]
# ## Esercio 9
# * Genera due array 3×3 con numeri casuali.
# * Concatenali orizzontalmente e verticalmente.
# * Calcola la somma di ciascuna riga e colonna della matrice risultante.

# %%
import numpy as np

# %%
v1 = np.random.randint(0, 11, (3,3))
v2 = np.random.randint(0, 11, (3,3))

# %%
orizzontale = np.concatenate((v1, v2), axis=1)
verticale = np.concatenate((v1, v2), axis=0)

# %%
somma_riga = np.sum(orizzontale, axis=1)
somma_riga
# Out:
# array([26, 34, 25])

# %%
somma_colonna = np.sum(orizzontale, axis=0)
somma_colonna
# Out:
# array([10, 24, 12,  7, 19, 13])
