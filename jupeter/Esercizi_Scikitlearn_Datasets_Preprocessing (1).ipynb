# %% [markdown]
# ## 1. sklearn.datasets: Caricamento e Generazione di Dataset
#
# ### Esercizio 1.1 (Base): Esplorazione Dataset Integrati
# Carica il dataset Wine e analizza le sue caratteristiche principali.

# %%
# Esercizio 1.1: Carica il dataset Wine e rispondi alle seguenti domande:
# 1. Quanti campioni e feature contiene?
# 2. Quante classi ci sono?
# 3. Quali sono i nomi delle feature?
# 4. Visualizza le prime 3 righe dei dati

# %%
from sklearn.datasets import load_wine
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.datasets import load_diabetes
from sklearn.datasets import make_regression
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import numpy as np

# %%
try:
    wines = load_wine()
except:
    print("Errore nel caricamento del dataset")

# %%
df_wines = pd.DataFrame(wines.data, columns=wines.feature_names)
df_wines
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
df_wines.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
n_campioni, n_feature = df_wines.shape
print(f"Numero di campioni (righe): {n_campioni}")
print(f"Numero di feature (colonne): {n_feature}")
# Out:
# Numero di campioni (righe): 178
# Numero di feature (colonne): 13

# %%
print(df_wines.columns)
# Out:
# Index(['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium',
#        'total_phenols', 'flavanoids', 'nonflavanoid_phenols',
#        'proanthocyanins', 'color_intensity', 'hue',
#        'od280/od315_of_diluted_wines', 'proline'],
#       dtype='object')

# %%
df_wines.head(3)
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
#
#    od280/od315_of_diluted_wines  proline
# 0                          3.92   1065.0
# 1                          3.40   1050.0
# 2                          3.17   1185.0

# %%
df_wines['target'] = wines.target
df_wines['target'].unique() 

print('Numero classi: ', len(df_wines['target'].unique()))
# Out:
# Numero classi:  3

# %% [markdown]
# ### Esercizio 1.2 (Intermedio): Generazione Dataset Personalizzato
# Crea un dataset sintetico per un problema di classificazione con specifiche caratteristiche.

# %%
# Esercizio 1.2: Genera un dataset di classificazione con:
# - 500 campioni
# - 8 feature totali (4 informative, 2 ridondanti)
# - 3 classi
# - 2 cluster per classe
# Poi visualizza le statistiche di base del dataset creato

# %%
X, y = make_classification(n_samples=500, n_features=8, n_informative=4, n_redundant=2, n_classes=3, n_clusters_per_class = 2, random_state=42)

print(f"\nShape del dataset: {X.shape}")
print(f"Numero di classi: {len(set(y))}")
print(f"Distribuzione delle classi: {list(y).count(0)} classe 0, {list(y).count(1)} classe 1")
# Out:
# Shape del dataset: (500, 8)
# Numero di classi: 3
# Distribuzione delle classi: 167 classe 0, 168 classe 1

# %% [markdown]
# ### Esercizio 1.3 (Avanzato): Confronto Dataset Reali vs Sintetici
# Confronta le caratteristiche del dataset Diabetes con un dataset sintetico di regressione.

# %%
# Esercizio 1.3: 
# 1. Carica il dataset Diabetes
# 2. Crea un dataset sintetico di regressione con le stesse dimensioni
# 3. Confronta le statistiche (media, std, range) delle feature

# %%
try:
    diabetes = load_diabetes()
except:
    print("Errore nel caricamento del dataset")

# %%
df_diabetes = pd.DataFrame(diabetes.data, columns = diabetes.feature_names)
df_diabetes

X_diabetes = diabetes.data
X_diabetes
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]], shape=(442, 10))

# %%
df_diabetes.shape
# Out:
# (442, 10)

# %%
X, y = make_regression(n_samples=442, n_features=10, noise=0.2, random_state=42)



print(f"Media delle etichette: {X.mean():.2f}")
print(f"Deviazione standard delle etichette: {X.std():.2f}")
print(f"Range delle etichette: {(X.max() - X.min()):.2f}")

print(f"Media delle etichette (diabetes): {X_diabetes.mean():.2f}")
print(f"Deviazione standard delle etichette (diabetes): {X_diabetes.std():.2f}")
print(f"Range delle etichette (diabetes): {(X_diabetes.max() - X_diabetes.min()):.2f}")
# Out:
# Media delle etichette: 0.01
# Deviazione standard delle etichette: 1.00
# Range delle etichette: 7.17
# Media delle etichette (diabetes): -0.00
# Deviazione standard delle etichette (diabetes): 0.05
# Range delle etichette (diabetes): 0.34

# %%
X_diabetes.shape, X.shape
# Out:
# ((442, 10), (442, 10))

# %% [markdown]
# ## 2. sklearn.preprocessing: Preprocessing dei Dati
#
# ### Esercizio 2.1 (Base): Scalatura Dati
# Applica diverse tecniche di scalatura sui dati del Wine dataset.

# %%
# Esercizio 2.1: Applica StandardScaler e MinMaxScaler al dataset Wine
# Confronta i risultati mostrando media e deviazione standard prima e dopo

# %%
scaler = StandardScaler()
scaler_data = scaler.fit_transform(wines.data)

print(scaler_data)

print(f"Media delle etichette: {scaler_data.mean():.2f}")
print(f"Deviazione standard delle etichette: {scaler_data.std():.2f}")


X_2 = wines.data

print(f"Media delle etichette: {X_2.mean():.2f}")
print(f"Deviazione standard delle etichette: {X_2.std():.2f}")
# Out:
# [[ 1.51861254 -0.5622498   0.23205254 ...  0.36217728  1.84791957
#    1.01300893]
#  [ 0.24628963 -0.49941338 -0.82799632 ...  0.40605066  1.1134493
#    0.96524152]
#  [ 0.19687903  0.02123125  1.10933436 ...  0.31830389  0.78858745
#    1.39514818]
#  ...
#  [ 0.33275817  1.74474449 -0.38935541 ... -1.61212515 -1.48544548
#    0.28057537]
#  [ 0.20923168  0.22769377  0.01273209 ... -1.56825176 -1.40069891
#    0.29649784]
#  [ 1.39508604  1.58316512  1.36520822 ... -1.52437837 -1.42894777
#   -0.59516041]]
# Media delle etichette: 0.00
# Deviazione standard delle etichette: 1.00
# Media delle etichette: 69.13
# Deviazione standard delle etichette: 215.75

# %%
X_2.shape, scaler_data.shape
# Out:
# ((178, 13), (178, 13))

# %%
min_max_scaler = MinMaxScaler()
normalized_data = min_max_scaler.fit_transform(X_2)

print(normalized_data)

print(f"Media delle etichette: {normalized_data.mean():.2f}")
print(f"Deviazione standard delle etichette: {normalized_data.std():.2f}")
# Out:
# [[0.84210526 0.1916996  0.57219251 ... 0.45528455 0.97069597 0.56134094]
#  [0.57105263 0.2055336  0.4171123  ... 0.46341463 0.78021978 0.55064194]
#  [0.56052632 0.3201581  0.70053476 ... 0.44715447 0.6959707  0.64693295]
#  ...
#  [0.58947368 0.69960474 0.48128342 ... 0.08943089 0.10622711 0.39728959]
#  [0.56315789 0.36561265 0.54010695 ... 0.09756098 0.12820513 0.40085592]
#  [0.81578947 0.66403162 0.73796791 ... 0.10569106 0.12087912 0.20114123]]
# Media delle etichette: 0.41
# Deviazione standard delle etichette: 0.22

# %% [markdown]
# ### Esercizio 2.2 (Intermedio): Gestione Dati Mancanti
# Crea e gestisci un dataset con valori mancanti usando diverse strategie di imputazione.

# %%
# Esercizio 2.2: 
# 1. Crea un array con valori mancanti (NaN) in posizioni casuali
# 2. Applica SimpleImputer con strategie: 'mean', 'median', 'most_frequent'
# 3. Confronta i risultati

# %%
X_new = np.random.randint(1, 10, size=(5, 5)).astype(float)

n_missing = 4
rows, cols = X_new.shape

nan_indices = set()
while len(nan_indices) < n_missing:
    i = np.random.randint(0, rows)
    j = np.random.randint(0, cols)
    nan_indices.add((i, j))

for i, j in nan_indices:
    X_new[i, j] = np.nan

X_new
# Out:
# array([[nan,  2.,  3.,  7.,  5.],
#        [ 6., nan,  4.,  7.,  5.],
#        [ 7.,  6.,  1., nan, nan],
#        [ 1.,  1.,  3.,  4.,  7.],
#        [ 2.,  7.,  6.,  2.,  1.]])

# %%
from sklearn.impute import SimpleImputer


imputer = SimpleImputer(strategy='mean')
imputed_data = imputer.fit_transform(X_new)

print(imputed_data)
# Out:
# [[4.  2.  3.  7.  5. ]
#  [6.  4.  4.  7.  5. ]
#  [7.  6.  1.  5.  4.5]
#  [1.  1.  3.  4.  7. ]
#  [2.  7.  6.  2.  1. ]]

# %%
imputer = SimpleImputer(strategy='median')
imputed_data = imputer.fit_transform(X_new)

print(imputed_data)
# Out:
# [[4.  2.  3.  7.  5. ]
#  [6.  4.  4.  7.  5. ]
#  [7.  6.  1.  5.5 5. ]
#  [1.  1.  3.  4.  7. ]
#  [2.  7.  6.  2.  1. ]]

# %%
imputer = SimpleImputer(strategy='most_frequent')
imputed_data = imputer.fit_transform(X_new)

print(imputed_data)
# Out:
# [[1. 2. 3. 7. 5.]
#  [6. 1. 4. 7. 5.]
#  [7. 6. 1. 7. 5.]
#  [1. 1. 3. 4. 7.]
#  [2. 7. 6. 2. 1.]]
