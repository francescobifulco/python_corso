# %%
# !pip freeze
# Out:
# asttokens==2.4.1
# colorama==0.4.6
# comm==0.2.2
# contourpy==1.3.2
# cycler==0.12.1
# debugpy==1.8.2
# decorator==5.1.1
# executing==2.0.1
# fonttools==4.58.5
# iniconfig==2.1.0
# ipykernel==6.29.5
# ipython==8.26.0
# jedi==0.19.1
# joblib==1.5.1
# jupyter_client==8.6.2
# jupyter_core==5.7.2
# kiwisolver==1.4.8
# matplotlib==3.10.3
# matplotlib-inline==0.1.7
# nest-asyncio==1.6.0
# numpy==2.3.1
# packaging==24.1
# pandas==2.3.1
# parso==0.8.4
# pillow==11.3.0
# platformdirs==4.2.2
# pluggy==1.6.0
# prompt_toolkit==3.0.47
# psutil==6.0.0
# pure_eval==0.2.3
# Pygments==2.18.0
# pyparsing==3.2.3
# pytest==8.4.1
# python-dateutil==2.9.0.post0
# pytz==2025.2
# pywin32==306
# pyzmq==26.0.3
# scikit-learn==1.7.0
# scipy==1.16.0
# seaborn==0.13.2
# six==1.16.0
# stack-data==0.6.3
# threadpoolctl==3.6.0
# tornado==6.4.1
# traitlets==5.14.3
# typing_extensions==4.12.2
# tzdata==2025.2
# wcwidth==0.2.13

# %%
# !pip freeze > requirements.txt

# %%
# !pip install requirements.txt
# Out:
# HINT: You are attempting to install a package literally named "requirements.txt" (which cannot exist). Consider using the '-r' flag to install the packages listed in requirements.txt
# ERROR: Could not find a version that satisfies the requirement requirements.txt (from versions: none)
# ERROR: No matching distribution found for requirements.txt
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\Roman\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## In questa sfida, ti chiediamo di creare un modello predittivo che risponda alla domanda: "Quali tipi di persone avevano maggiori probabilità di sopravvivere?" utilizzando i dati dei passeggeri (ad esempio nome, età, sesso, classe socioeconomica, ecc.).

# %%
import seaborn as sns
import pandas as pd

# %%
df_train = pd.read_csv('train.csv')
df_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_test = pd.read_csv('test.csv')
df_test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df_train.drop(columns='Cabin')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df_test.drop(columns='Cabin')
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Embarked
# ...
