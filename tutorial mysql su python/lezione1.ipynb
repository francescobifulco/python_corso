# %% [markdown]
# ### Connettore di prova MySQL
#
# Per verificare se l'installazione ha avuto successo, o se hai già "MySQL" Connettore di dialogo " Installato, creare una pagina Python con Il seguente contenuto

# %%
import mysql.connector

# %% [markdown]
# ### Creazione di una connessione
#
# Inizia creando una connessione al database.
# Usa il nome utente e la password dal tuo database MySQL

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="root"
)

print(f'connssione al DataBase con successo: {mydb}')
# Out:
# connssione al DataBase con successo: <mysql.connector.connection.MySQLConnection object at 0x00000166468853D0>
