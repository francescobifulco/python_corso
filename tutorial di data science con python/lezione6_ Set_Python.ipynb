# %%
frutta = {'Mela', 'Pera', 'Banana'}
frutta
# Out:
# {'Banana', 'Mela', 'Pera'}

# %%
# Rimozione del duplicato
frutta = {'Mela', 'Pera', 'Banana', 'Mela'}
frutta
# Out:
# {'Banana', 'Mela', 'Pera'}

# %%
# Set dalla lista
numeri = set([1,2,3,4,5])
numeri
# Out:
# {1, 2, 3, 4, 5}

# %%
elenco = set()
elenco
# Out:
# set()

# %%
# Aggiunta di elementi nel Set
elenco.add('Mario')
elenco.add('Giovanni')
elenco.add('Mario')
elenco
# Out:
# {'Giovanni', 'Mario'}

# %%
persona = {'Giovanni', 'Mario', 'Valeria'}
persona
# Out:
# {'Giovanni', 'Mario', 'Valeria'}

# %%
# Rimozione con Exception se non esistw
# persona.remove('Marika')
# persona

# %%
# Rimozione sicura
persona.discard('Marika')
persona
# Out:
# {'Giovanni', 'Mario', 'Valeria'}

# %%
elemento = persona.pop()
elemento
# Out:
# 'Valeria'

# %%
a = {'Giovanni', 'Mario', 'Valeria', 'Marika'}
b = {'Mela', 'Pera', 'Banana', 'MArika'}

# %%
# Unione
print(a | b)
# Out:
# {'Marika', 'Mela', 'Banana', 'MArika', 'Valeria', 'Giovanni', 'Pera', 'Mario'}

# %%
# Intersezione
print(a & b)
# Out:
# set()

# %%
# Differenza
print(a - b)
# Out:
# {'Marika', 'Mario', 'Valeria', 'Giovanni'}

# %%
# Diff. Simmetrica
print(a ^ b)
# Out:
# {'Mela', 'Banana', 'Marika', 'MArika', 'Valeria', 'Giovanni', 'Pera', 'Mario'}

# %%
# Frozen Set
frozen = frozenset(['Mela', 'Banana', 'Mela'])
frozen
# Out:
# frozenset({'Banana', 'Mela'})
