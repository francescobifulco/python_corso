# %%
#Inizializzazione lista
lista = ['Musica', 'Astronomia', 'Programmazione']

# %%
#Aggiunta dinamica di un elemento
lista.append('Moto')

# %%
#Stampa dell'intera lista
lista
# Out:
# ['Musica', 'Astronomia', 'Programmazione', 'Moto']

# %%
#Stampa un solo elemento
lista[1]
# Out:
# 'Astronomia'

# %%
#Verifica presenza di un elemento
i = lista.index('Programmazione')
i
# Out:
# 2

# %%
if i > 0: 
    print('Trovato')
else:
    print('Non trovato')
# Out:
# Trovato

# %%
if 'Armonia' in lista:
    indice = list.index('Armonia')
    if indice > 0:
        print('Trovato')
else:
    print('Non trovato')
# Out:
# Non trovato

# %%
lista
# Out:
# ['Musica', 'Astronomia', 'Programmazione', 'Moto']

# %%
#Inserire in una posizione specifica
lista.insert(1, 'Hiking')
lista
# Out:
# ['Musica', 'Hiking', 'Astronomia', 'Programmazione', 'Moto']

# %%
#Aggiora un elemento
lista[1] = 'Snorkeling'
lista
# Out:
# ['Musica', 'Snorkeling', 'Astronomia', 'Programmazione', 'Moto']

# %%
#Elimina un elemento della lista
del lista[1]
lista
# Out:
# ['Musica', 'Astronomia', 'Programmazione', 'Moto']

# %%
#Conta gli elementi presenti in lista
lunghezza = len(lista)
print(f'La lunghezza della lista è: {lunghezza}')
# Out:
# La lunghezza della lista è: 4

# %%
#Conta quante volte e ripetuto questo elemento: Astronomia
contatore = lista.count('Astronomia')
print(f'Astronomia è presente: {contatore}')
# Out:
# Astronomia è presente: 1
